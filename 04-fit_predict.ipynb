# %%
import os
from torch.utils.data import DataLoader,Dataset
import torchvision.transforms as transforms
from PIL import Image
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import cv2
#import albumentations as A
import difflib
from colorama import Style
import random
import tqdm

from sklearn import preprocessing
from sklearn.model_selection import train_test_split

import shutil


DEBUG = False
target = 'action'

# %%
dtrain = pd.read_csv('01-train_image1.csv')
dtrain = dtrain[dtrain['image'] == dtrain['image']]

dtrain.reset_index(drop = True, inplace = True)
dtrain.head()
# Out:
#      id                 date  employee  action                datex  \
# 0  1256  2022-05-24 08:08:36         2    15.0  05-24-2022 08:08:36
# 1  1257  2022-05-24 08:08:37         2     4.0  05-24-2022 08:08:37
# 2  1258  2022-05-24 08:12:13         3    15.0  05-24-2022 08:12:13
# 3  1259  2022-05-24 08:12:25         3     2.0  05-24-2022 08:12:25
# 4  1260  2022-05-24 08:12:42         3    12.0  05-24-2022 08:12:42
#
#                      image
# 0  05-24-2022_08_08_36.png
# 1  05-24-2022_08_08_37.png
# 2  05-24-2022_08_12_13.png
# 3  05-24-2022_08_12_25.png
# 4  05-24-2022_08_12_42.png

# %%
le = preprocessing.LabelEncoder()
dtrain[target] = le.fit_transform(dtrain[target].values)

# %%
for u in sorted(dtrain[target].unique()):
    print(u, dtrain[dtrain[target] == u].shape[0])
# Out:
# 0 6
# 1 129
# 2 54
# 3 184
# 4 176
# 5 22
# 6 8
# 7 10
# 8 2
# 9 6
# 10 131
# 11 52
# 12 185
# 13 175
# 14 21
# 15 7
# 16 12

# %%
print(dtrain.shape)

dtrain = dtrain[dtrain[target] != 8]
#dtrain = dtrain[dtrain[target] != 9]
#dtrain = dtrain[dtrain[target] != 0]

print(dtrain.shape)

le = preprocessing.LabelEncoder()
dtrain[target] = le.fit_transform(dtrain[target].values)

for u in sorted(dtrain[target].unique()):
    print(u, dtrain[dtrain[target] == u].shape[0])
# Out:
# (1180, 6)
# (1178, 6)
# 0 6
# 1 129
# 2 54
# 3 184
# 4 176
# 5 22
# 6 8
# 7 10
# 8 6
# 9 131
# 10 52
# 11 185
# 12 175
# 13 21
# 14 7
# 15 12

# %%
try:
    shutil.rmtree('./train_class/')
except:
    pass

# %%
classes = sorted(dtrain[target].unique())

train_dir = './train_image/'
class_dir = './train_class/'

for c in classes:    
    
    train_images = dtrain['image'][dtrain[target] == c]
    
    c = str(c)
    os.makedirs(os.path.join(class_dir, c), exist_ok = True)    
    
    for image in train_images:
        image_src = train_dir + image
        image_dst = os.path.join(class_dir, c, image)
        shutil.copyfile(image_src, image_dst)

# %%
import os
import PIL
import tensorflow as tf

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '4'

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
# Out:
# 2022-09-06 07:54:59.136442: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
batch_size = 8
img_height = 512 + 128
img_width  = 512 + 128

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  class_dir,
  validation_split = 0.2,
  subset = "training",
  seed = 0,
  image_size = (img_height, img_width),
  batch_size = batch_size
)
# Out:
# Found 1160 files belonging to 16 classes.
# Using 928 files for training.
# 2022-09-06 07:55:00.751184: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-06 07:55:00.752735: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-06 07:55:00.753138: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-06 07:55:00.754344: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-06 07:55:00.755858: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-06 07:55:00.756249: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-06 07:55:00.756552: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-06 07:55:02.467170: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-06 07:55:02.467522: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-06 07:55:02.467778: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-06 07:55:02.468247: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3761 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  class_dir,
  validation_split = 0.2,
  subset = "validation",
  seed = 0,
  image_size = (img_height, img_width),
  batch_size = batch_size
)
# Out:
# Found 1160 files belonging to 16 classes.
# Using 232 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['0', '1', '10', '11', '12', '13', '14', '15', '2', '3', '4', '5', '6', '7', '8', '9']

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (8, 640, 640, 3)
# (8,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
num_classes = len(class_names)

model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 3, padding='same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding='same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.1),
    layers.Flatten(),
    layers.Dense(128, activation = 'relu'),
    layers.Dense(num_classes)
])

# %%
def scheduler(epoch, lr):
    decay_rate = 0.1
    decay_step = 10
    
    if epoch % decay_step == 0 and epoch:
        return lr * decay_rate
    
    return lr


EarlyStopping = tf.keras.callbacks.EarlyStopping(
    monitor = "val_accuracy",
    min_delta = 0,
    patience  = 20,
    verbose = 1,
    mode = 'max',
    baseline = None,
    restore_best_weights = True,
)

weights_file = '01-model.h5'
ModelCheckpoint = tf.keras.callbacks.ModelCheckpoint(
    weights_file,
    monitor = 'val_accuracy',
    mode = 'max',
    save_best_only = True,
    verbose = 1,
)


callback = [
    EarlyStopping, 
    ModelCheckpoint, 
    tf.keras.callbacks.LearningRateScheduler(scheduler, verbose = 1)
]

# %%
opt = keras.optimizers.Adam(learning_rate = 0.001)

model.compile(
    optimizer = opt,
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics = ['accuracy'],    
)

# %%
epochs = 1250

def fitting():
    history = model.fit(
        train_ds,
        validation_data = val_ds,
        epochs = epochs,
        callbacks = callback    
    )
    return(history)

history = fitting()
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 1/1250
# 2022-09-06 07:55:06.288440: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8302
# 2022-09-06 07:55:08.095237: W tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2022-09-06 07:55:08.097402: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.6
# 2022-09-06 07:55:08.097434: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at ptxas
# 2022-09-06 07:55:08.097520: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2022-09-06 07:55:08.312067: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 115/116 [============================>.] - ETA: 0s - loss: 3.0715 - accuracy: 0.1522
# Epoch 1: val_accuracy improved from -inf to 0.15948, saving model to 01-model.h5
# 116/116 [==============================] - 12s 66ms/step - loss: 3.0657 - accuracy: 0.1519 - val_loss: 2.2848 - val_accuracy: 0.1595 - lr: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 2/1250
# 115/116 [============================>.] - ETA: 0s - loss: 2.0471 - accuracy: 0.2609
# Epoch 2: val_accuracy improved from 0.15948 to 0.32759, saving model to 01-model.h5
# 116/116 [==============================] - 7s 57ms/step - loss: 2.0426 - accuracy: 0.2608 - val_loss: 1.8146 - val_accuracy: 0.3276 - lr: 0.0010
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 3/1250
# 115/116 [============================>.] - ETA: 0s - loss: 1.7221 - accuracy: 0.3522
# Epoch 3: val_accuracy improved from 0.32759 to 0.41379, saving model to 01-model.h5
# 116/116 [==============================] - 6s 54ms/step - loss: 1.7233 - accuracy: 0.3524 - val_loss: 1.5876 - val_accuracy: 0.4138 - lr: 0.0010
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 4/1250
# 115/116 [============================>.] - ETA: 0s - loss: 1.4653 - accuracy: 0.4185
# Epoch 4: val_accuracy improved from 0.41379 to 0.43534, saving model to 01-model.h5
# 116/116 [==============================] - 6s 56ms/step - loss: 1.4678 - accuracy: 0.4213 - val_loss: 1.4437 - val_accuracy: 0.4353 - lr: 0.0010
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 5/1250
# 115/116 [============================>.] - ETA: 0s - loss: 1.3404 - accuracy: 0.4728
# Epoch 5: val_accuracy improved from 0.43534 to 0.44828, saving model to 01-model.h5
# 116/116 [==============================] - 6s 55ms/step - loss: 1.3380 - accuracy: 0.4731 - val_loss: 1.3940 - val_accuracy: 0.4483 - lr: 0.0010
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 6/1250
# 115/116 [============================>.] - ETA: 0s - loss: 1.2825 - accuracy: 0.4750
# Epoch 6: val_accuracy did not improve from 0.44828
# 116/116 [==============================] - 6s 49ms/step - loss: 1.2794 - accuracy: 0.4752 - val_loss: 1.4513 - val_accuracy: 0.4095 - lr: 0.0010
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 7/1250
# 115/116 [============================>.] - ETA: 0s - loss: 1.2009 - accuracy: 0.5098
# Epoch 7: val_accuracy improved from 0.44828 to 0.49569, saving model to 01-model.h5
# 116/116 [==============================] - 9s 77ms/step - loss: 1.1993 - accuracy: 0.5108 - val_loss: 1.3783 - val_accuracy: 0.4957 - lr: 0.0010
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 8/1250
# 115/116 [============================>.] - ETA: 0s - loss: 1.1278 - accuracy: 0.5467
# Epoch 8: val_accuracy did not improve from 0.49569
# 116/116 [==============================] - 6s 49ms/step - loss: 1.1354 - accuracy: 0.5453 - val_loss: 1.4130 - val_accuracy: 0.4483 - lr: 0.0010
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 9/1250
# 115/116 [============================>.] - ETA: 0s - loss: 1.0823 - accuracy: 0.5663
# Epoch 9: val_accuracy did not improve from 0.49569
# 116/116 [==============================] - 6s 49ms/step - loss: 1.0822 - accuracy: 0.5668 - val_loss: 1.4415 - val_accuracy: 0.4828 - lr: 0.0010
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 10/1250
# 115/116 [============================>.] - ETA: 0s - loss: 1.0363 - accuracy: 0.5848
# Epoch 10: val_accuracy did not improve from 0.49569
# 116/116 [==============================] - 6s 49ms/step - loss: 1.0369 - accuracy: 0.5841 - val_loss: 1.3762 - val_accuracy: 0.4612 - lr: 0.0010
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 11/1250
# 116/116 [==============================] - ETA: 0s - loss: 0.9158 - accuracy: 0.6466
# Epoch 11: val_accuracy improved from 0.49569 to 0.50000, saving model to 01-model.h5
# 116/116 [==============================] - 7s 60ms/step - loss: 0.9158 - accuracy: 0.6466 - val_loss: 1.4134 - val_accuracy: 0.5000 - lr: 1.0000e-04
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 12/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.8395 - accuracy: 0.6815
# Epoch 12: val_accuracy improved from 0.50000 to 0.50431, saving model to 01-model.h5
# 116/116 [==============================] - 7s 60ms/step - loss: 0.8527 - accuracy: 0.6789 - val_loss: 1.4741 - val_accuracy: 0.5043 - lr: 1.0000e-04
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 13/1250
# 116/116 [==============================] - ETA: 0s - loss: 0.8335 - accuracy: 0.6541
# Epoch 13: val_accuracy did not improve from 0.50431
# 116/116 [==============================] - 6s 48ms/step - loss: 0.8335 - accuracy: 0.6541 - val_loss: 1.4889 - val_accuracy: 0.5000 - lr: 1.0000e-04
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 14/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.8129 - accuracy: 0.6880
# Epoch 14: val_accuracy improved from 0.50431 to 0.51724, saving model to 01-model.h5
# 116/116 [==============================] - 8s 67ms/step - loss: 0.8120 - accuracy: 0.6875 - val_loss: 1.4857 - val_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 15/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.8031 - accuracy: 0.6902
# Epoch 15: val_accuracy did not improve from 0.51724
# 116/116 [==============================] - 6s 48ms/step - loss: 0.8020 - accuracy: 0.6918 - val_loss: 1.5221 - val_accuracy: 0.4957 - lr: 1.0000e-04
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 16/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7919 - accuracy: 0.6859
# Epoch 16: val_accuracy did not improve from 0.51724
# 116/116 [==============================] - 6s 49ms/step - loss: 0.7903 - accuracy: 0.6875 - val_loss: 1.5097 - val_accuracy: 0.5172 - lr: 1.0000e-04
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 17/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7723 - accuracy: 0.6957
# Epoch 17: val_accuracy improved from 0.51724 to 0.52155, saving model to 01-model.h5
# 116/116 [==============================] - 7s 61ms/step - loss: 0.7739 - accuracy: 0.6961 - val_loss: 1.5098 - val_accuracy: 0.5216 - lr: 1.0000e-04
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 18/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7590 - accuracy: 0.7152
# Epoch 18: val_accuracy did not improve from 0.52155
# 116/116 [==============================] - 6s 48ms/step - loss: 0.7565 - accuracy: 0.7166 - val_loss: 1.5179 - val_accuracy: 0.5086 - lr: 1.0000e-04
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 19/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7615 - accuracy: 0.7033
# Epoch 19: val_accuracy did not improve from 0.52155
# 116/116 [==============================] - 6s 48ms/step - loss: 0.7589 - accuracy: 0.7037 - val_loss: 1.5309 - val_accuracy: 0.5086 - lr: 1.0000e-04
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 20/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7451 - accuracy: 0.7120
# Epoch 20: val_accuracy improved from 0.52155 to 0.52586, saving model to 01-model.h5
# 116/116 [==============================] - 7s 61ms/step - loss: 0.7431 - accuracy: 0.7123 - val_loss: 1.5417 - val_accuracy: 0.5259 - lr: 1.0000e-04
#
# Epoch 21: LearningRateScheduler setting learning rate to 1.0000000474974514e-05.
# Epoch 21/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7244 - accuracy: 0.7250
# Epoch 21: val_accuracy did not improve from 0.52586
# 116/116 [==============================] - 6s 48ms/step - loss: 0.7221 - accuracy: 0.7252 - val_loss: 1.5452 - val_accuracy: 0.5216 - lr: 1.0000e-05
# Epoch 22: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 22/1250
# 116/116 [==============================] - ETA: 0s - loss: 0.7211 - accuracy: 0.7284
# Epoch 22: val_accuracy did not improve from 0.52586
# 116/116 [==============================] - 6s 49ms/step - loss: 0.7211 - accuracy: 0.7284 - val_loss: 1.5506 - val_accuracy: 0.5259 - lr: 1.0000e-05
#
# Epoch 23: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 23/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7159 - accuracy: 0.7391
# Epoch 23: val_accuracy did not improve from 0.52586
# 116/116 [==============================] - 6s 48ms/step - loss: 0.7136 - accuracy: 0.7392 - val_loss: 1.5526 - val_accuracy: 0.5259 - lr: 1.0000e-05
#
# Epoch 24: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 24/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7135 - accuracy: 0.7250
# Epoch 24: val_accuracy did not improve from 0.52586
# 116/116 [==============================] - 6s 48ms/step - loss: 0.7133 - accuracy: 0.7252 - val_loss: 1.5582 - val_accuracy: 0.5259 - lr: 1.0000e-05
#
# Epoch 25: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 25/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7130 - accuracy: 0.7228
# Epoch 25: val_accuracy did not improve from 0.52586
# 116/116 [==============================] - 6s 48ms/step - loss: 0.7128 - accuracy: 0.7220 - val_loss: 1.5611 - val_accuracy: 0.5259 - lr: 1.0000e-05
#
# Epoch 26: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 26/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7227 - accuracy: 0.7250
# Epoch 26: val_accuracy did not improve from 0.52586
# 116/116 [==============================] - 6s 48ms/step - loss: 0.7212 - accuracy: 0.7252 - val_loss: 1.5634 - val_accuracy: 0.5216 - lr: 1.0000e-05
#
# Epoch 27: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 27/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7184 - accuracy: 0.7315
# Epoch 27: val_accuracy did not improve from 0.52586
# 116/116 [==============================] - 6s 48ms/step - loss: 0.7146 - accuracy: 0.7328 - val_loss: 1.5668 - val_accuracy: 0.5216 - lr: 1.0000e-05
#
# Epoch 28: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 28/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7136 - accuracy: 0.7228
# Epoch 28: val_accuracy did not improve from 0.52586
# 116/116 [==============================] - 6s 48ms/step - loss: 0.7117 - accuracy: 0.7241 - val_loss: 1.5674 - val_accuracy: 0.5216 - lr: 1.0000e-05
#
# Epoch 29: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 29/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7095 - accuracy: 0.7250
# Epoch 29: val_accuracy did not improve from 0.52586
# 116/116 [==============================] - 6s 49ms/step - loss: 0.7062 - accuracy: 0.7274 - val_loss: 1.5722 - val_accuracy: 0.5172 - lr: 1.0000e-05
#
# Epoch 30: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 30/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7150 - accuracy: 0.7228
# Epoch 30: val_accuracy did not improve from 0.52586
# 116/116 [==============================] - 6s 48ms/step - loss: 0.7132 - accuracy: 0.7231 - val_loss: 1.5742 - val_accuracy: 0.5259 - lr: 1.0000e-05
#
# Epoch 31: LearningRateScheduler setting learning rate to 1.0000000656873453e-06.
# Epoch 31/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7103 - accuracy: 0.7272
# Epoch 31: val_accuracy did not improve from 0.52586
# 116/116 [==============================] - 6s 48ms/step - loss: 0.7081 - accuracy: 0.7284 - val_loss: 1.5744 - val_accuracy: 0.5259 - lr: 1.0000e-06
#
# Epoch 32: LearningRateScheduler setting learning rate to 1.0000001111620804e-06.
# Epoch 32/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7114 - accuracy: 0.7293
# Epoch 32: val_accuracy did not improve from 0.52586
# 116/116 [==============================] - 6s 49ms/step - loss: 0.7103 - accuracy: 0.7317 - val_loss: 1.5742 - val_accuracy: 0.5259 - lr: 1.0000e-06
#
# Epoch 33: LearningRateScheduler setting learning rate to 1.0000001111620804e-06.
# Epoch 33/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7077 - accuracy: 0.7435
# Epoch 33: val_accuracy did not improve from 0.52586
# 116/116 [==============================] - 5s 47ms/step - loss: 0.7084 - accuracy: 0.7435 - val_loss: 1.5746 - val_accuracy: 0.5259 - lr: 1.0000e-06
#
# Epoch 34: LearningRateScheduler setting learning rate to 1.0000001111620804e-06.
# Epoch 34/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7045 - accuracy: 0.7326
# Epoch 34: val_accuracy did not improve from 0.52586
# 116/116 [==============================] - 6s 48ms/step - loss: 0.7034 - accuracy: 0.7328 - val_loss: 1.5748 - val_accuracy: 0.5259 - lr: 1.0000e-06
#
# Epoch 35: LearningRateScheduler setting learning rate to 1.0000001111620804e-06.
# Epoch 35/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7064 - accuracy: 0.7207
# Epoch 35: val_accuracy did not improve from 0.52586
# 116/116 [==============================] - 6s 48ms/step - loss: 0.7061 - accuracy: 0.7209 - val_loss: 1.5754 - val_accuracy: 0.5259 - lr: 1.0000e-06
#
# Epoch 36: LearningRateScheduler setting learning rate to 1.0000001111620804e-06.
# Epoch 36/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7107 - accuracy: 0.7239
# Epoch 36: val_accuracy did not improve from 0.52586
# 116/116 [==============================] - 6s 48ms/step - loss: 0.7088 - accuracy: 0.7241 - val_loss: 1.5757 - val_accuracy: 0.5259 - lr: 1.0000e-06
#
# Epoch 37: LearningRateScheduler setting learning rate to 1.0000001111620804e-06.
# Epoch 37/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.6940 - accuracy: 0.7293
# Epoch 37: val_accuracy did not improve from 0.52586
# 116/116 [==============================] - 6s 50ms/step - loss: 0.7062 - accuracy: 0.7274 - val_loss: 1.5760 - val_accuracy: 0.5259 - lr: 1.0000e-06
#
# Epoch 38: LearningRateScheduler setting learning rate to 1.0000001111620804e-06.
# Epoch 38/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7068 - accuracy: 0.7272
# Epoch 38: val_accuracy did not improve from 0.52586
# 116/116 [==============================] - 6s 49ms/step - loss: 0.7036 - accuracy: 0.7295 - val_loss: 1.5760 - val_accuracy: 0.5259 - lr: 1.0000e-06
#
# Epoch 39: LearningRateScheduler setting learning rate to 1.0000001111620804e-06.
# Epoch 39/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7074 - accuracy: 0.7304
# Epoch 39: val_accuracy did not improve from 0.52586
# 116/116 [==============================] - 6s 48ms/step - loss: 0.7056 - accuracy: 0.7306 - val_loss: 1.5767 - val_accuracy: 0.5259 - lr: 1.0000e-06
#
# Epoch 40: LearningRateScheduler setting learning rate to 1.0000001111620804e-06.
# Epoch 40/1250
# 115/116 [============================>.] - ETA: 0s - loss: 0.7027 - accuracy: 0.7293Restoring model weights from the end of the best epoch: 20.
#
# Epoch 40: val_accuracy did not improve from 0.52586
# 116/116 [==============================] - 6s 49ms/step - loss: 0.7072 - accuracy: 0.7284 - val_loss: 1.5770 - val_accuracy: 0.5259 - lr: 1.0000e-06
# Epoch 40: early stopping

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(history.epoch))

plt.figure(figsize = (8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label = 'Training Accuracy')
plt.plot(epochs_range, val_acc, label = 'Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label = 'Training Loss')
plt.plot(epochs_range, val_loss, label = 'Validation Loss')
plt.legend(loc = 'upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
from keras.models import load_model

model = load_model('01-model.h5')

opt = keras.optimizers.Adam(learning_rate = 0.001)

model.compile(
    optimizer = opt,
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
    metrics = ['accuracy'],    
)

# %%
dtest = pd.read_csv('01-test_image.csv')
dtest
# Out:
#         id                 date                datex                    image
# 0      135  2022-05-22 11:51:06  05-22-2022 11:51:06  05-22-2022_11_51_06.png
# 1      136  2022-05-22 11:51:25  05-22-2022 11:51:25  05-22-2022_11_51_25.png
# 2      137  2022-05-22 12:04:27  05-22-2022 12:04:27  05-22-2022_12_04_27.png
# 3      138  2022-05-22 12:07:56  05-22-2022 12:07:56  05-22-2022_12_07_56.png
# 4      139  2022-05-22 12:08:10  05-22-2022 12:08:10  05-22-2022_12_08_10.png
# ...    ...                  ...                  ...                      ...
# 1116  1251  2022-05-24 07:57:00  05-24-2022 07:57:00  05-24-2022_07_57_00.png
# 1117  1252  2022-05-24 07:57:32  05-24-2022 07:57:32  05-24-2022_07_57_32.png
# 1118  1253  2022-05-24 07:57:34  05-24-2022 07:57:34  05-24-2022_07_57_34.png
# 1119  1254  2022-05-24 07:57:39  05-24-2022 07:57:39  05-24-2022_07_57_39.png
# 1120  1255  2022-05-24 07:57:41  05-24-2022 07:57:41  05-24-2022_07_57_41.png
#
# [1121 rows x 4 columns]

# %%
from tensorflow.keras.preprocessing import image


dtest['employee'] = 0
dtest[target] = 0

for i in tqdm.tqdm(dtest.index):
    img = dtest.loc[i, 'image']
    if img == img:
        #img = img.split('/')[2]
        img = './test_image/' + img
        img = image.load_img(
            img, 
            target_size = (img_width, img_height)
        )
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis = 0)
        #x = x / 255

        images = np.vstack([x])
        classes = model.predict(images, batch_size = 1, verbose = False)
        out = np.argmax(classes)
        dtest.loc[i, target] = out
# Out:
# 100%|███████████████████████████████████████████| 1121/1121 [00:55<00:00, 20.26it/s]

# %%
dtest[target] = le.inverse_transform(dtest[target].values)

dtest['id'] = dtest['id'].astype(int)
dtest[target] = dtest[target].astype(int)
dtest['action'] = dtest['action'].astype(int)

dtest[['id', 'employee', target]].to_csv('02.csv', index = False)

dtest[['id', 'employee', target]].head()
# Out:
#     id  employee  action
# 0  135         0      11
# 1  136         0       3
# 2  137         0       2
# 3  138         0       2
# 4  139         0      11

# %%
for u in sorted(dtest[target].unique()):
    print(u, dtest[dtest[target] == u].shape[0])
# Out:
# 0 14
# 1 92
# 2 105
# 3 167
# 4 266
# 5 3
# 6 2
# 7 5
# 9 47
# 10 58
# 11 148
# 12 60
# 13 6
# 14 9
# 15 2
# 16 137

# %%
st1 = pd.read_csv('01.csv')
st1.head()
# Out:
#     id  employee  action
# 0  135         7       0
# 1  136         7       0
# 2  137         7       0
# 3  138         7       0
# 4  139        11       0

# %%
st1['action'] = dtest[target].values
st1.head()
# Out:
#     id  employee  action
# 0  135         7      11
# 1  136         7       3
# 2  137         7       2
# 3  138         7       2
# 4  139        11      11

# %%
st1['id']       = st1['id'].astype(int)
st1['employee'] = st1['employee'].astype(int)
st1['action']   = st1['action'].astype(int)

st1.to_csv('full.csv', index = False)

# %%
st1
# Out:
#         id  employee  action
# 0      135         7      11
# 1      136         7       3
# 2      137         7       2
# 3      138         7       2
# 4      139        11      11
# ...    ...       ...     ...
# 1116  1251         5       4
# 1117  1252         5       4
# 1118  1253         5       4
# 1119  1254         5      10
# 1120  1255         5       4
#
# [1121 rows x 3 columns]

# %% [markdown]
# https://lk.hacks-ai.ru/758261/champ
